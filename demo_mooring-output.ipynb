# %% [markdown]
# # Formats Demo
#
# Demonstration of SeaSenseLib with different input file formats for moored instrumentation.

# %%
import seasenselib as ssl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 4)

# %% [markdown]
# ## SeaBird MicroCAT (CNV Format)

# %%
# Load SeaBird MicroCAT time series data and plot salinity
microcat_data = ssl.read("../examples/denmark-strait-ds-m1-17.cnv")
ssl.plot('time-series', microcat_data, parameters=['salinity'], title="MicroCAT Salinity Time Series")
# Out:
# INFO:pycnv: Opening file: ../examples/denmark-strait-ds-m1-17.cnv
# WARNING:pycnv:Could not compute datetime dates based on timeM
# WARNING:pycnv:Could not compute datetime dates based on timeS
# INFO:pycnv:Dates computed based on start_date and time_interval
# Computing date
# INFO:seasenselib.pipeline.pipeline:Starting pipeline with 7 stages
# INFO:seasenselib.pipeline.mapping.handlers.mapping_runner:Mapped 5 variables
# INFO:seasenselib.pipeline.derivation.handlers.derivation_runner:Derived 6 parameter(s)
# INFO:seasenselib.pipeline.metadata_extraction.handlers.extraction_runner:Extracted metadata from 2 source(s)
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.cf_convention:Applied CF-1.13 conventions
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.acdd_convention:Applied ACDD conventions
# INFO:seasenselib.pipeline.pipeline:Pipeline completed successfully

# %% [markdown]
# ## Nortek Aquadopp (DAT Format)
#
# Nortek Format Key:
#   - 'nortek-ascii' - Nortek ASCII format reader
#
# For Nortek Aquadopps, you should use:
#
#     aquadopp_data = ssl.read("filename.dat", file_format='nortek-ascii', header_file="filename.hdr")

# %%
# Load Nortek Aquadopp velocity data and plot u,v components
aquadopp_data = ssl.read("../examples/DSC18_477102.dat",
  file_format='nortek-ascii', header_file="../examples/DSC18_477102.hdr")
ssl.plot('time-series', aquadopp_data, parameters=['east_velocity', 'north_velocity'], title="Aquadopp Velocity Components")
# Out:
# INFO:seasenselib.readers.base:Initialized reader NortekAsciiReader for '../examples/DSC18_477102.dat'
# INFO:seasenselib.readers.base:Loading data from '../examples/DSC18_477102.dat'
# INFO:seasenselib.pipeline.pipeline:Starting pipeline with 7 stages
# INFO:seasenselib.pipeline.mapping.handlers.mapping_runner:Mapped 3 variables
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'density': missing input 'salinity'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'potential_temperature': missing input 'salinity'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'conservative_temperature': missing input 'salinity'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'absolute_salinity': missing input 'salinity'
# INFO:seasenselib.pipeline.metadata_extraction.handlers.extraction_runner:Extracted metadata from 2 source(s)
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.cf_convention:Applied CF-1.13 conventions
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.acdd_convention:Applied ACDD conventions
# INFO:seasenselib.pipeline.pipeline:Pipeline completed successfully

# %% [markdown]
# ## RBR TR1050 Thermistor (MAT Format)
#
# Other formats available include:
# - 'rbr-rsk' - Auto reader for RSK files
# - 'rbr-rsk-default' - Default RSK reader
# - 'rbr-rsk-legacy' - Legacy RSK reader
# - 'rbr-matlab' - MATLAB format reader
# - 'rbr-matlab-legacy' - Legacy MATLAB format reader
# - 'rbr-matlab-rsktools' - MATLAB RSKtools export format
# - 'rbr-ascii' - ASCII format reader

# %%
# Load RBR TR1050 thermistor data from Ruskin MAT export and plot temperature
tr1050_data = ssl.read("../examples/DSE18_013889_20180827_1349.mat", file_format='rbr-matlab')
ssl.plot('time-series', tr1050_data, parameters=['temperature'], title="RBR TR1050 Temperature")
# Out:
# INFO:seasenselib.readers.base:Initialized reader RbrMatlabReader for '../examples/DSE18_013889_20180827_1349.mat'
# INFO:seasenselib.readers.base:Loading data from '../examples/DSE18_013889_20180827_1349.mat'
# INFO:seasenselib.readers.base:Initialized reader RbrMatlabLegacyReader for '../examples/DSE18_013889_20180827_1349.mat'
# INFO:seasenselib.readers.base:Loading data from '../examples/DSE18_013889_20180827_1349.mat'
# INFO:seasenselib.pipeline.pipeline:Starting pipeline with 7 stages
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'density': units for 'temperature' are ['�c'], expected one of ['degc', 'degree_celsius']
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'depth': missing input 'pressure'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'potential_temperature': units for 'temperature' are ['�c'], expected one of ['degc', 'degree_celsius']
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'conservative_temperature': units for 'temperature' are ['�c'], expected one of ['degc', 'degree_celsius']
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'absolute_salinity': missing input 'salinity'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'speed_of_sound': units for 'temperature' are ['�c'], expected one of ['degc', 'degree_celsius']
# INFO:seasenselib.pipeline.metadata_extraction.handlers.extraction_runner:Extracted metadata from 2 source(s)
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.cf_convention:Applied CF-1.13 conventions
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.acdd_convention:Applied ACDD conventions
# INFO:seasenselib.pipeline.pipeline:Pipeline completed successfully

# %% [markdown]
# ## RBR Solo T (RSK Format)

# %%
# Load RBR Solo T data from native Ruskin format and plot temperature
solo_data = ssl.read("../examples/DSE18_101647_20180827_1551.rsk")
ssl.plot('time-series', solo_data, parameters=['temperature'], title="RBR Solo T Temperature")
# Out:
# INFO:seasenselib.readers.base:Initialized reader RbrRskAutoReader for '../examples/DSE18_101647_20180827_1551.rsk'
# INFO:seasenselib.readers.base:Loading data from '../examples/DSE18_101647_20180827_1551.rsk'
# INFO:seasenselib.readers.base:Initialized reader RbrRskLegacyReader for '../examples/DSE18_101647_20180827_1551.rsk'
# INFO:seasenselib.readers.base:Loading data from '../examples/DSE18_101647_20180827_1551.rsk'
# INFO:seasenselib.pipeline.pipeline:Starting pipeline with 7 stages
# INFO:seasenselib.pipeline.mapping.handlers.mapping_runner:Mapped 1 variables
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'density': units for 'temperature' are ['°c'], expected one of ['degc', 'degree_celsius']
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'depth': missing input 'pressure'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'potential_temperature': units for 'temperature' are ['°c'], expected one of ['degc', 'degree_celsius']
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'conservative_temperature': units for 'temperature' are ['°c'], expected one of ['degc', 'degree_celsius']
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'absolute_salinity': missing input 'salinity'
# WARNING:seasenselib.pipeline.derivation.handlers.derivation_runner:Skipped derivation 'speed_of_sound': units for 'temperature' are ['°c'], expected one of ['degc', 'degree_celsius']
# INFO:seasenselib.pipeline.metadata_extraction.handlers.extraction_runner:Extracted metadata from 2 source(s)
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.cf_convention:Applied CF-1.13 conventions
# INFO:seasenselib.pipeline.metadata_enrichment.handlers.acdd_convention:Applied ACDD conventions
# INFO:seasenselib.pipeline.pipeline:Pipeline completed successfully

# %% [markdown]
# ## SeaSenseLib Format Keys
#
#   The following format keys can be used with `ssl.read(filename, file_format='key')`:
#
#   **ADCP (Acoustic Doppler Current Profiler):**
#   - `'adcp-matlab-uhhds'`: ADCP MATLAB UHHDS format
#   - `'adcp-matlab-rdadcp'`: ADCP MATLAB RDADCP format
#
#   **CSV/Generic:**
#   - `'csv'`: Comma-separated values format
#   - `'netcdf'`: Network Common Data Form
#
#   **Nortek:**
#   - `'nortek-ascii'`: Nortek ASCII format (requires header file)
#
#   **RBR (Richard Brancker Research):**
#   - `'rbr-rsk'`: RBR RSK native format (auto reader)
#   - `'rbr-rsk-default'`: RBR RSK default reader
#   - `'rbr-rsk-legacy'`: RBR RSK legacy format
#   - `'rbr-matlab'`: RBR MATLAB export format
#   - `'rbr-matlab-legacy'`: RBR MATLAB legacy format
#   - `'rbr-matlab-rsktools'`: RBR MATLAB RSKtools export
#   - `'rbr-ascii'`: RBR ASCII format
#
#   **RCM (Anderaa):**
#   - `'rcm-matlab'`: RCM MATLAB format
#
#   **SeaBird:**
#   - `'sbe-cnv'`: SeaBird CNV format
#   - `'sbe-ascii'`: SeaBird ASCII format
#
#   **Seasun:**
#   - `'seasun-tob'`: Seasun TOB format
#
#   **Usage Example:**
#   ```python
#   data = ssl.read('filename.ext', file_format='format-key')
#   # For formats requiring header files (e.g., Nortek):
#   data = ssl.read('data.dat', file_format='nortek-ascii', header_file='data.hdr')
